# %%
import dask.dataframe as dd

# %%
from dask.distributed import Client

client = Client(n_workers=3, threads_per_worker = 2, memory_limit='4G')
display(client)
# Out:
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44525 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:34509' processes=3 threads=6, memory=11.18 GiB>
# Task exception was never retrieved
# future: <Task finished name='Task-1101979' coro=<Client._gather.<locals>.wait() done, defined at /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/client.py:2189> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/client.py", line 2198, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
types = {
    'Summons Number': 'int32',
    'Plate ID': 'string',
    'Registration State': 'string',
    'Plate Type': 'string',
    'Issue Date': 'string',
    'Violation Code': 'int16',
    'Vehicle Body Type': 'string',
    'Vehicle Make': 'string',
    'Issuing Agency': 'string',
    'Street Code1': 'int32',
    'Street Code2': 'int32',
    'Street Code3': 'int32',
    'Vehicle Expiration Date': 'int32',
    'Violation Location': 'string',
    'Violation Precinct': 'int32',
    'Issuer Precinct': 'int32',
    'Issuer Code': 'int32',
    'Issuer Command': 'string',
    'Issuer Squad': 'string',
    'Violation Time': 'string',
    'Time First Observed': 'string',
    'Violation County': 'string',
    'Violation In Front Of Or Opposite': 'string',
    'House Number': 'string',
    'Street Name': 'string',
    'Intersecting Street': 'string',
    'Date First Observed': 'int32',
    'Law Section': 'int32',
    'Sub Division': 'string',
    'Violation Legal Code': 'string',
    'Days Parking In Effect': 'string',
    'From Hours In Effect': 'string',
    'To Hours In Effect': 'string',
    'Vehicle Color': 'string',
    'Unregistered Vehicle?': 'string',
    'Vehicle Year': 'int16',
    'Meter Number': 'string',
    'Feet From Curb': 'int16',
    'Violation Post Code': 'string',
    'Violation Description': 'string',
    'No Standing or Stopping Violation': 'string',
    'Hydrant Violation': 'string',
    'Double Parking Violation': 'string'
}

# %%
ddf = dd.read_csv("/mnt/c/Users/Yannik/Downloads/Parking_Violations_Issued_-_Fiscal_Year_2023.csv",\
                    dtype=types, blocksize='100e6')

# %%
ddf = ddf.rename(columns=lambda x: x.lower().rstrip().replace(' ', '_'))

# %%
len(ddf.columns)
# Out:
# 43

# %%
ddf = ddf.dropna(how='all').compute()
# Out:
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# 2023-06-07 16:57:12,444 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42595 (pid=5005) exceeded 95% memory budget. Restarting...
# 2023-06-07 16:57:12,617 - distributed.scheduler - ERROR - Couldn't gather keys {"('dropna-748a79881212c5ae9cee471df91c6b67', 9)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 7)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 17)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 12)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 16)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 10)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 21)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 26)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 18)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 13)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 20)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 25)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 14)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 24)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 19)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 4)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 6)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 3)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 1)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 0)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 22)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 15)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 11)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 2)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 23)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 8)": ['tcp://127.0.0.1:42595'], "('dropna-748a79881212c5ae9cee471df91c6b67', 5)": ['tcp://127.0.0.1:42595']} state: ['queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued', 'queued'] workers: ['tcp://127.0.0.1:42595']
# NoneType: None
# 2023-06-07 16:57:12,676 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 9)
# NoneType: None
# 2023-06-07 16:57:12,677 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 7)
# NoneType: None
# 2023-06-07 16:57:12,678 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 17)
# NoneType: None
# 2023-06-07 16:57:12,679 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 12)
# NoneType: None
# 2023-06-07 16:57:12,680 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 16)
# NoneType: None
# 2023-06-07 16:57:12,682 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 10)
# NoneType: None
# 2023-06-07 16:57:12,683 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 21)
# NoneType: None
# 2023-06-07 16:57:12,684 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 26)
# NoneType: None
# 2023-06-07 16:57:12,686 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 18)
# NoneType: None
# 2023-06-07 16:57:12,688 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 13)
# NoneType: None
# 2023-06-07 16:57:12,689 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 20)
# NoneType: None
# 2023-06-07 16:57:12,691 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 25)
# NoneType: None
# 2023-06-07 16:57:12,692 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 14)
# NoneType: None
# 2023-06-07 16:57:12,693 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 24)
# NoneType: None
# 2023-06-07 16:57:12,694 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 19)
# NoneType: None
# 2023-06-07 16:57:12,695 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 4)
# NoneType: None
# 2023-06-07 16:57:12,698 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 6)
# NoneType: None
# 2023-06-07 16:57:12,701 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 3)
# NoneType: None
# 2023-06-07 16:57:12,703 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 1)
# NoneType: None
# 2023-06-07 16:57:12,706 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 0)
# NoneType: None
# 2023-06-07 16:57:12,712 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 22)
# NoneType: None
# 2023-06-07 16:57:12,721 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 15)
# NoneType: None
# 2023-06-07 16:57:12,723 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 11)
# NoneType: None
# 2023-06-07 16:57:12,725 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 2)
# NoneType: None
# 2023-06-07 16:57:12,727 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 23)
# NoneType: None
# 2023-06-07 16:57:12,729 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 8)
# NoneType: None
# 2023-06-07 16:57:12,730 - distributed.scheduler - ERROR - Shut down workers that don't have promised key: ['tcp://127.0.0.1:42595'], ('dropna-748a79881212c5ae9cee471df91c6b67', 5)
# NoneType: None
# 2023-06-07 16:57:12,742 - distributed.client - WARNING - Couldn't gather 27 keys, rescheduling {"('dropna-748a79881212c5ae9cee471df91c6b67', 9)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 7)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 17)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 12)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 16)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 10)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 21)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 26)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 18)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 13)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 20)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 25)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 14)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 24)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 19)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 4)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 6)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 3)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 1)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 0)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 22)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 15)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 11)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 2)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 23)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 8)": ('tcp://127.0.0.1:42595',), "('dropna-748a79881212c5ae9cee471df91c6b67', 5)": ('tcp://127.0.0.1:42595',)}
# 2023-06-07 16:57:12,754 - distributed.nanny - WARNING - Restarting worker
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 ddf = ddf.dropna(how='all').compute()
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/base.py:310, in DaskMethodsMixin.compute(self, **kwargs)
#     286 def compute(self, **kwargs):
#     287     """Compute this dask collection
#     288
#     289     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     308     dask.compute
#     309     """
# --> 310     (result,) = compute(self, traverse=False, **kwargs)
#     311     return result
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/base.py:595, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     592     keys.append(x.__dask_keys__())
#     593     postcomputes.append(x.__dask_postcompute__())
# --> 595 results = schedule(dsk, keys, **kwargs)
#     596 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/client.py:3227, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3225         should_rejoin = False
#    3226 try:
# -> 3227     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3228 finally:
#    3229     for f in futures.values():
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/client.py:2361, in Client.gather(self, futures, errors, direct, asynchronous)
#    2359 else:
#    2360     local_worker = None
# -> 2361 return self.sync(
#    2362     self._gather,
#    2363     futures,
#    2364     errors=errors,
#    2365     direct=direct,
#    2366     local_worker=local_worker,
#    2367     asynchronous=asynchronous,
#    2368 )
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/utils.py:351, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     349     return future
#     350 else:
# --> 351     return sync(
#     352         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     353     )
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/utils.py:414, in sync(loop, func, callback_timeout, *args, **kwargs)
#     412 else:
#     413     while not e.is_set():
# --> 414         wait(10)
#     416 if error:
#     417     typ, exc, tb = error
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/utils.py:403, in sync.<locals>.wait(timeout)
#     401 def wait(timeout):
#     402     try:
# --> 403         return e.wait(timeout)
#     404     except KeyboardInterrupt:
#     405         loop.add_callback(cancel)
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/anaconda3/envs/bigdata/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
ddf.columns
# Out:
# Index(['summons_number', 'plate_id', 'registration_state', 'plate_type',
#        'issue_date', 'violation_code', 'vehicle_body_type', 'vehicle_make',
#        'issuing_agency', 'street_code1', 'street_code2', 'street_code3',
#        'vehicle_expiration_date', 'violation_location', 'violation_precinct',
#        'issuer_precinct', 'issuer_code', 'issuer_command', 'issuer_squad',
#        'violation_time', 'time_first_observed', 'violation_county',
#        'violation_in_front_of_or_opposite', 'house_number', 'street_name',
#        'intersecting_street', 'date_first_observed', 'law_section',
#        'sub_division', 'violation_legal_code', 'days_parking_in_effect',
#        'from_hours_in_effect', 'to_hours_in_effect', 'vehicle_color',
#        'unregistered_vehicle?', 'vehicle_year', 'meter_number',
#        'feet_from_curb', 'violation_post_code', 'violation_description',
#        'no_standing_or_stopping_violation', 'hydrant_violation',
#        'double_parking_violation'],
#       dtype='object')

# %%
ddf.describe().compute()
# Out:
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# Task exception was never retrieved
# future: <Task finished name='Task-1258167' coro=<Client._gather.<locals>.wait() done, defined at /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/client.py:2189> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/distributed/client.py", line 2198, in wait
#     raise AllExit()
# distributed.client.AllExit
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#        summons_number  violation_code  street_code1  street_code2  \
# count    1.439267e+07    1.439267e+07  1.439267e+07  1.439267e+07
# mean     5.061279e+08    3.406388e+01  1.693997e+04  1.467889e+04
# std      3.731281e+08    1.758463e+01  2.194346e+04  2.083847e+04
# min     -4.243315e+08    0.000000e+00  0.000000e+00  0.000000e+00
# 25%      4.315427e+08    3.600000e+01  0.000000e+00  0.000000e+00
# 50%      4.990314e+08    3.600000e+01  1.642000e+04  1.361000e+04
# 75%      5.408947e+08    4.700000e+01  3.729000e+04  3.473000e+04
# max      2.011710e+09    9.900000e+01  9.826000e+04  9.831000e+04
#
#        street_code3  vehicle_expiration_date  violation_precinct  \
# count  1.439267e+07             1.439267e+07        1.439267e+07
# mean   1.452148e+04             1.729517e+07        3.051500e+01
# std    2.092158e+04             2.519452e+07        3.952614e+01
# min    0.000000e+00             0.000000e+00        0.000000e+00
# 25%    0.000000e+00             0.000000e+00        0.000000e+00
# 50%    1.279000e+04             2.023059e+07        2.300000e+01
# 75%    3.489000e+04             2.025033e+07        8.400000e+01
# max    9.828000e+04             8.888889e+07        9.710000e+02
#
#        issuer_precinct   issuer_code  date_first_observed   law_section  \
# count     1.439267e+07  1.439267e+07         1.439267e+07  1.439267e+07
# mean      2.960404e+01  2.140650e+05         1.097146e+05  7.507163e+02
# std       5.063996e+01  2.172868e+05         1.485558e+06  3.785173e+02
# min       0.000000e+00  0.000000e+00         0.000000e+00  0.000000e+00
# 25%       0.000000e+00  0.000000e+00         0.000000e+00  4.080000e+02
# 50%       1.900000e+01  3.610210e+05         0.000000e+00  1.180000e+03
# 75%       8.400000e+01  3.722770e+05         0.000000e+00  1.180000e+03
# max       9.970000e+02  9.998140e+05         2.028011e+07  8.040000e+03
#
#        vehicle_year  feet_from_curb
# count  1.439267e+07    1.439267e+07
# mean   1.680321e+03    6.300144e-02
# std    7.505950e+02    5.722993e-01
# min    0.000000e+00    0.000000e+00
# 25%    2.011000e+03    0.000000e+00
# 50%    2.017000e+03    0.000000e+00
# 75%    2.020000e+03    0.000000e+00
# max    2.069000e+03    7.000000e+01

# %%
ddf.to_parquet('../data/0_RAW/parking_ticket_2023.parquet')
# Out:
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /home/yannik/anaconda3/envs/bigdata/lib/python3.9/site-packages/dask/dataframe/io/csv.py:195: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %%
client.shutdown()
